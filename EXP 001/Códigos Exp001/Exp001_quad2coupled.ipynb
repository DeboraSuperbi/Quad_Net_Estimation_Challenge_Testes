# %% [markdown]
# # EXP001 - Numeric experiments for state estimation
#
# Two coupled oscillators.

# %%
# import libraries
import numpy as np, scipy as sp, matplotlib.pyplot as plt
import quadratureNetwork as qnet #library that implement the oscillators
from multiprocessing import Pool
import multiprocessing, joblib, os

def netExperiment(Rf):

  # FILENAME (to save data)
  fileName = r"exp001\Rf_%08d"%Rf
  
  # execute only if the file does not exist
  if not(os.path.isfile(fileName+".npz")):
    # PARAMETERS of each oscillator: R1, R2, C1, C2, R3, C3, R4, R5, R6, R7, Vcc, Vd, Ra, Rb, R, Rf
    params = np.array([[10e+03, R2[0], 2.2e-06, 2.2e-06, 12e+03, 2.2e-06, 22e+03, 4.7e+03, 4.7e+03, 22e+03,  15, 0.7, Ra, Rb, R, Rf],
                       [10e+03, R2[1], 2.2e-06, 2.2e-06, 12e+03, 2.2e-06, 22e+03, 4.7e+03, 4.7e+03, 22e+03,  15, 0.7, Ra, Rb, R, Rf]])

    # TRANSIENT SIMULATION
    x0tr = 0.01*np.random.rand(n*N) #random initial conditions
    X001 = qnet.intRK(qnet.quadNetOde, x0tr, tTr, (Adj, params)) #simulate systems transient
    X001 = qnet.intRK(qnet.quadNetOde, X001[-1, :], t, (Adj, params)) #simulate permanent regime

    # Compute the order parameter
    pc001 = qnet.orderParameter(X001, n=3, hilbert=True)
    pcMean = np.mean(pc001)
    pcStd = np.std(pc001)
    
    # # DANGER ZONE ==> SAVE DATA
    # print("saving file: "+fileName)
    
    # # # PYTHON FORMAT
    # # np.savez_compressed(fileName+".npz", Rf=Rf, pcMean=pcMean, pcStd=pcStd)
    
    # # MATLAB FORMAT
    # mdic = {"params": params, "x": X001, "Rf": Rf, "pc": pc001, "pcMean": pcMean, "pcStd": pcStd}
    # sp.io.savemat(fileName+".mat", mdic)

  else:
    #the file exists, do not execute simulation
    pcMean = 0
  
  return pcMean

# PARAMETERS of the NETWORK
# adjacency matrix (two mutually coupled oscillator)
Adj = np.array([[0, 1],  # 1 <== 2
                [1, 0]], # 2 <== 1
                dtype=np.float64)
N = len(Adj) #number of oscillators

# PARAMETERS of the OSCILLATORS
# model to obtain R2 value according to the desired natural frequency
freq2R2 = np.poly1d(np.load('m10_polyModel_freq_to_R2.npz')['m10']) # define the model
freqOsc = [3.80, 4.00] # DEFINE FREQUENCY OF ALL OSCILLATORS
R2 = np.array([freq2R2(R2_i) for R2_i in freqOsc], dtype=np.float64)
Ra,  Rb,  R = 100e+3, 100e+3, 100e+3
Rfvec = np.arange(0e+03, 101e+03, 1e+03)
params = np.empty((N, 16), dtype=np.float64)
Rfvec_len = len(Rfvec)
print("Simulating %d experiments..."%Rfvec_len)

# PARAMETERS of the SIMULATION
h = .005 #integration step (h=0.001)
tfTr = 60 #transient time
tf = 120 #final time
n = 3 #system order
tTr = np.arange(0, tfTr, h) #transient time vector
t = np.arange(0, tf, h) #time vector
N001 = len(t) #length of time vector

R2

# # PARALLEL PROCESSING
# num_cores = multiprocessing.cpu_count()
# pcMean = joblib.Parallel(n_jobs=num_cores, verbose=50)(
#   joblib.delayed(netExperiment)(k)for k in Rfvec)
# Out:
# Simulating 101 experiments...
# array([ 9.84, 11.  ])

# %%
# import libraries
import numpy as np, scipy as sp, matplotlib.pyplot as plt
import quadratureNetwork as qnet #library that implement the oscillators
from multiprocessing import Pool
import multiprocessing, joblib, os

def netExperiment(Rf):

  import os
  folder = "exp001"
  os.makedirs(folder, exist_ok=True)

  # FILENAME (to save data)
  fileName = r"exp001\Rf_%08d"%Rf
  
  # execute only if the file does not exist
  if not(os.path.isfile(fileName+".npz")):
    # PARAMETERS of each oscillator: R1, R2, C1, C2, R3, C3, R4, R5, R6, R7, Vcc, Vd, Ra, Rb, R, Rf
    params = np.array([[10e+03, R2[0], 2.2e-06, 2.2e-06, 12e+03, 2.2e-06, 22e+03, 4.7e+03, 4.7e+03, 22e+03,  15, 0.7, Ra, Rb, R, Rf],
                       [10e+03, R2[1], 2.2e-06, 2.2e-06, 12e+03, 2.2e-06, 22e+03, 4.7e+03, 4.7e+03, 22e+03,  15, 0.7, Ra, Rb, R, Rf]])

    # TRANSIENT SIMULATION
    x0tr = 0.01*np.random.rand(n*N) #random initial conditions
    X001 = qnet.intRK(qnet.quadNetOde, x0tr, tTr, (Adj, params)) #simulate systems transient
    X001 = qnet.intRK(qnet.quadNetOde, X001[-1, :], t, (Adj, params)) #simulate permanent regime

    # Compute the order parameter
    pc001 = qnet.orderParameter(X001, n=3, hilbert=True)
    pcMean = np.mean(pc001)
    pcStd = np.std(pc001)
    
    # DANGER ZONE ==> SAVE DATA
    print("saving file: "+fileName)
    
    # # PYTHON FORMAT
    # np.savez_compressed(fileName+".npz", Rf=Rf, pcMean=pcMean, pcStd=pcStd)
    
    # MATLAB FORMAT
    mdic = {"params": params, "x": X001, "Rf": Rf, "pc": pc001, "pcMean": pcMean, "pcStd": pcStd}
    sp.io.savemat(fileName+".mat", mdic)

  else:
    #the file exists, do not execute simulation
    pcMean = 0
  
  return pcMean

# PARAMETERS of the NETWORK
# adjacency matrix (two mutually coupled oscillator)
Adj = np.array([[0, 1],  # 1 <== 2
                [1, 0]], # 2 <== 1
                dtype=np.float64)
N = len(Adj) #number of oscillators

# PARAMETERS of the OSCILLATORS
# model to obtain R2 value according to the desired natural frequency
freq2R2 = np.poly1d(np.load('m10_polyModel_freq_to_R2.npz')['m10']) # define the model
freqOsc = [3.80, 4.00] # DEFINE FREQUENCY OF ALL OSCILLATORS
R2 = np.array([freq2R2(R2_i) for R2_i in freqOsc], dtype=np.float64)
Ra,  Rb,  R = 100e+3, 100e+3, 100e+3
Rfvec = np.arange(0e+03, 101e+03, 1e+03)
params = np.empty((N, 16), dtype=np.float64)
Rfvec_len = len(Rfvec)
print("Simulating %d experiments..."%Rfvec_len)

# PARAMETERS of the SIMULATION
h = .005 #integration step (h=0.001)
tfTr = 60 #transient time
tf = 120 #final time
n = 3 #system order
tTr = np.arange(0, tfTr, h) #transient time vector
t = np.arange(0, tf, h) #time vector
N001 = len(t) #length of time vector

# PARALLEL PROCESSING
num_cores = multiprocessing.cpu_count()
pcMean = joblib.Parallel(n_jobs=num_cores, verbose=50)(
  joblib.delayed(netExperiment)(k)for k in Rfvec)
# Out:
# Simulating 101 experiments...
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done   1 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done   2 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done   3 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done   4 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done   5 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done   6 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done   7 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done   8 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done   9 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done  10 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=12)]: Done  11 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=12)]: Done  12 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=12)]: Done  13 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=12)]: Done  14 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=12)]: Done  15 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=12)]: Done  16 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=12)]: Done  17 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=12)]: Done  18 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=12)]: Done  19 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=12)]: Done  20 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=12)]: Done  21 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=12)]: Done  22 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=12)]: Done  23 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=12)]: Done  24 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=12)]: Done  25 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=12)]: Done  27 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=12)]: Done  28 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=12)]: Done  29 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=12)]: Done  30 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=12)]: Done  31 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=12)]: Done  32 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=12)]: Done  33 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=12)]: Done  34 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=12)]: Done  35 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=12)]: Done  36 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=12)]: Done  37 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=12)]: Done  38 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=12)]: Done  39 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=12)]: Done  40 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=12)]: Done  41 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=12)]: Done  42 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=12)]: Done  43 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=12)]: Done  44 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=12)]: Done  45 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=12)]: Done  46 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=12)]: Done  47 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=12)]: Done  48 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=12)]: Done  49 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=12)]: Done  50 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=12)]: Done  51 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=12)]: Done  52 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=12)]: Done  53 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=12)]: Done  54 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=12)]: Done  55 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=12)]: Done  56 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=12)]: Done  57 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=12)]: Done  58 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=12)]: Done  59 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=12)]: Done  60 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=12)]: Done  61 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=12)]: Done  62 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=12)]: Done  63 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=12)]: Done  64 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=12)]: Done  65 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=12)]: Done  66 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=12)]: Done  67 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=12)]: Done  68 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=12)]: Done  69 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=12)]: Done  70 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=12)]: Done  71 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=12)]: Done  72 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=12)]: Done  73 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=12)]: Done  74 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=12)]: Done  75 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=12)]: Done  76 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=12)]: Done  77 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=12)]: Done  78 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=12)]: Done  81 out of 101 | elapsed: 15.3min remaining:  3.8min
# [Parallel(n_jobs=12)]: Done  84 out of 101 | elapsed: 15.6min remaining:  3.2min
# [Parallel(n_jobs=12)]: Done  87 out of 101 | elapsed: 16.9min remaining:  2.7min
# [Parallel(n_jobs=12)]: Done  90 out of 101 | elapsed: 17.0min remaining:  2.1min
# [Parallel(n_jobs=12)]: Done  93 out of 101 | elapsed: 17.2min remaining:  1.5min
# [Parallel(n_jobs=12)]: Done  96 out of 101 | elapsed: 17.4min remaining:   54.3s
# [Parallel(n_jobs=12)]: Done  99 out of 101 | elapsed: 18.0min remaining:   21.8s
# [Parallel(n_jobs=12)]: Done 101 out of 101 | elapsed: 18.0min finished

# %% [markdown]
# ## Example how to load all files

# %%
# import libraries
import numpy as np, scipy as sp, matplotlib.pyplot as plt, os
import quadratureNetwork as qnet #library that implement the oscillators

folderName = 'exp001'

allFiles = os.listdir(folderName)
print(allFiles)

Rf = []
pcMean = []
pcStd = []
for file in allFiles:
  if file[-3:] == 'mat':
    npzfile = sp.io.loadmat(folderName+'\\'+file)
    Rf.append(npzfile['Rf'][0,0])
    pcMean.append(npzfile['pcMean'][0,0])
    pcStd.append(npzfile['pcStd'][0,0])

Rf = np.array(Rf)
pcMean = np.array(pcMean)
pcStd = np.array(pcStd)
sorIdx = np.argsort(Rf)
Rf, pcMean, pcStd = Rf[sorIdx], pcMean[sorIdx], pcStd[sorIdx]
# Out:
# ['Rf_00000000.mat', 'Rf_00001000.mat', 'Rf_00002000.mat', 'Rf_00003000.mat', 'Rf_00004000.mat', 'Rf_00005000.mat', 'Rf_00006000.mat', 'Rf_00007000.mat', 'Rf_00008000.mat', 'Rf_00009000.mat', 'Rf_00010000.mat', 'Rf_00011000.mat', 'Rf_00012000.mat', 'Rf_00013000.mat', 'Rf_00014000.mat', 'Rf_00015000.mat', 'Rf_00016000.mat', 'Rf_00017000.mat', 'Rf_00018000.mat', 'Rf_00019000.mat', 'Rf_00020000.mat', 'Rf_00021000.mat', 'Rf_00022000.mat', 'Rf_00023000.mat', 'Rf_00024000.mat', 'Rf_00025000.mat', 'Rf_00026000.mat', 'Rf_00027000.mat', 'Rf_00028000.mat', 'Rf_00029000.mat', 'Rf_00030000.mat', 'Rf_00031000.mat', 'Rf_00032000.mat', 'Rf_00033000.mat', 'Rf_00034000.mat', 'Rf_00035000.mat', 'Rf_00036000.mat', 'Rf_00037000.mat', 'Rf_00038000.mat', 'Rf_00039000.mat', 'Rf_00040000.mat', 'Rf_00041000.mat', 'Rf_00042000.mat', 'Rf_00043000.mat', 'Rf_00044000.mat', 'Rf_00045000.mat', 'Rf_00046000.mat', 'Rf_00047000.mat', 'Rf_00048000.mat', 'Rf_00049000.mat', 'Rf_00050000.mat', 'Rf_00051000.mat', 'Rf_00052000.mat', 'Rf_00053000.mat', 'Rf_00054000.mat', 'Rf_00055000.mat', 'Rf_00056000.mat', 'Rf_00057000.mat', 'Rf_00058000.mat', 'Rf_00059000.mat', 'Rf_00060000.mat', 'Rf_00061000.mat', 'Rf_00062000.mat', 'Rf_00063000.mat', 'Rf_00064000.mat', 'Rf_00065000.mat', 'Rf_00066000.mat', 'Rf_00067000.mat', 'Rf_00068000.mat', 'Rf_00069000.mat', 'Rf_00070000.mat', 'Rf_00071000.mat', 'Rf_00072000.mat', 'Rf_00073000.mat', 'Rf_00074000.mat', 'Rf_00075000.mat', 'Rf_00076000.mat', 'Rf_00077000.mat', 'Rf_00078000.mat', 'Rf_00079000.mat', 'Rf_00080000.mat', 'Rf_00081000.mat', 'Rf_00082000.mat', 'Rf_00083000.mat', 'Rf_00084000.mat', 'Rf_00085000.mat', 'Rf_00086000.mat', 'Rf_00087000.mat', 'Rf_00088000.mat', 'Rf_00089000.mat', 'Rf_00090000.mat', 'Rf_00091000.mat', 'Rf_00092000.mat', 'Rf_00093000.mat', 'Rf_00094000.mat', 'Rf_00095000.mat', 'Rf_00096000.mat', 'Rf_00097000.mat', 'Rf_00098000.mat', 'Rf_00099000.mat', 'Rf_00100000.mat']

# %%
plt.figure(figsize=(10,2))
plt.title(r'Order parameter vs $R_f$')
plt.xlabel(r'$R_f (\Omega)$')
plt.ylabel(r'Phase coherence')
plt.plot(Rf, pcMean+pcStd, '--', c='C02', lw=.3)
plt.plot(Rf, pcMean-pcStd, '--', c='C02', lw=.3)

plt.plot(Rf[Rf==10000], pcMean[Rf==10000], '.', c='C03', ms=20, zorder=10)
plt.text(Rf[Rf==10000], pcMean[Rf==10000]-.07, '$R_f=10000$', ha='center', va='top')

plt.plot(Rf[Rf==20000], pcMean[Rf==20000], '.', c='C03', ms=20, zorder=10)
plt.text(Rf[Rf==20000]+6000, pcMean[Rf==20000]-.01, '$R_f=20000$', ha='center', va='top')

plt.plot(Rf[Rf==70000], pcMean[Rf==70000], '.', c='C03', ms=20, zorder=10)
plt.text(Rf[Rf==70000], pcMean[Rf==70000]-.07, '$R_f=70000$', ha='center', va='top')


plt.plot(Rf, pcMean, '-', ms=15)
plt.xlim(min(Rf), max(Rf))
# plt.xlim(300e3, 500e3)
plt.ylim(0.0, 1.02)
plt.grid(1, which='both');

# %%
import networkx as nx, numpy as np, matplotlib.pyplot as plt

# Create an empty graph
G = nx.Graph()

# Define the adjacency matrix
Adj = np.array([[0, 1],  # 1 <== 2
                [1, 0]], # 2 <== 1
                dtype=np.float64)

# Add nodes to the graph
nodes = list(range(len(Adj)))
G.add_nodes_from(nodes)


# Add edges based on the adjacency matrix
for i in range(len(Adj)):
    for j in range(len(Adj[i])):
        if Adj[i][j] == 1:
            G.add_edge(i, j)

# Draw the network
pos = nx.spring_layout(G)  # Use spring layout for better visualization
nx.draw(G, pos, with_labels=True, font_weight='bold', node_size=500, node_color='skyblue', font_size=15, edge_color='black')

# Show the plot
plt.show()

# %% [markdown]
# ## Loading just 1 file

# %%
# import libraries
import numpy as np, scipy as sp, matplotlib.pyplot as plt, os
import quadratureNetwork as qnet #library that implement the oscillators

folderName = 'exp001'
# fileName = 'Rf_00010000.mat'
# fileName = 'Rf_00020000.mat'
fileName = 'Rf_00070000.mat'

npzfile = sp.io.loadmat(folderName+'\\'+fileName)
params = npzfile['params']
x = npzfile['x']
Rf = npzfile['Rf']
pc = npzfile['pc'][0]
pcMean = npzfile['pcMean']
pcStd = npzfile['pcStd']

t = np.arange(0, len(x), 1)*0.005

# %%
plt.figure(figsize=(10,1))
plt.plot(t, pc)
plt.xlim(0, 120); plt.ylim(0,1)
# Out:
# (0.0, 1.0)
